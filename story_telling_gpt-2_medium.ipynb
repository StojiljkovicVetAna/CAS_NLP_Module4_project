# %% [markdown]
# # Finetuned GPT-2-Medium

# %% [markdown]
# ## The Base Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, Trainer, TrainingArguments
import torch
from transformers import pipeline

# %%
pipe_base = pipeline(
    "text-generation",
    model="openai-community/gpt2-medium",
    device="cuda",
)

prompt = "Once upon a time there was a fairy"

baseline = pipe_base(
    prompt,
    max_new_tokens=200,
    min_new_tokens=100,
    do_sample=True,  
    temperature=0.9,
    top_p=0.95,       
    #repetition_penalty=1.1,
    #no_repeat_ngram_size=3 
)

baseline = baseline[0]["generated_text"] # extracts the generated text
print(baseline)
# Out:
# Device set to use cuda
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time there was a fairy, named Aladdin. And a boy named Jasmine. And they went to the palace of Aladdin to find the true prince, who would destroy evil and bring glory to the kingdom. But in the end, it didn't quite work out.Aladdin was captured, and Jasmine was left behind. So he went off to save her, and soon he was on his own. But one day when he found a small patch of grass, his hope was shattered when he was ambushed by Jasmine's friends, who wanted revenge against the kingdom. That's when Aladdin learned to be brave. And as he goes to the castle of the king, Jasmine tells him: "This is where we belong. Here we belong. Let us be true to ourselves."So here we have the story of Jasmine, and Aladdin. In order to keep them as one family, Aladdin and Jasmine must take on each other's mantle, and protect their own secrets, as well

# %% [markdown]
# ---

# %% [markdown]
# ## The Checkpoints

# %%
checkpoint_path_16655 = "models_gpt2_medium/results/checkpoint-16655"

# %%
tokenizer_16655 = AutoTokenizer.from_pretrained(checkpoint_path_16655)
model_16655 = AutoModelForCausalLM.from_pretrained(checkpoint_path_16655).to("cuda")

# %%
pipe_ckpt_16655 = pipeline(
    "text-generation",
    model=model_16655,
    tokenizer=tokenizer_16655,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
ft_output_16655 = pipe_ckpt_16655(
    prompt,
    max_new_tokens=200,
    min_new_tokens=100,
    do_sample=True,
    temperature=0.9,
    top_p=0.95,
    #repetition_penalty=1.1,
    #no_repeat_ngram_size=3
)

finetuned_16655 = ft_output_16655[0]["generated_text"]
print(finetuned_16655)
# Out:
# Once upon a time there was a fairy queen, and at night she sat by a long line of rocks, as if they were rock stars, for they were so bright and shining in the moonlight. So, when she was tired, she sat down and said: “My lord, what is to be done to make the rocks go?” “I will go,” said the first, “but first you must go up to the hill-side and find a hole.” So she took out a large rock, and at the first stroke the tree went straight into it, and there she sat down in the hole.” So she turned it around, and when he got there he found a hole, and then the door was made, and there she went again, and a hole, and a hole, and the door opened. “Oh! it is a well,” said the second, “but you must do something to get it.” “You

# %% [markdown]
# ---

# %%
checkpoint_path_33310 = "models_gpt2_medium/results/checkpoint-33310"

# %%
tokenizer_33310 = AutoTokenizer.from_pretrained(checkpoint_path_33310)
model_33310 = AutoModelForCausalLM.from_pretrained(checkpoint_path_33310).to("cuda")

# %%
pipe_ckpt_33310 = pipeline(
    "text-generation",
    model=model_33310,
    tokenizer=tokenizer_33310,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
ft_output_33310 = pipe_ckpt_33310(
    prompt,
    max_new_tokens=200,
    min_new_tokens=100,
    do_sample=True,
    temperature=0.9,
    top_p=0.95,
    #repetition_penalty=1.1,
    #no_repeat_ngram_size=3
)

finetuned_33310 = ft_output_33310[0]["generated_text"]
print(finetuned_33310)
# Out:
# Once upon a time there was a fairy, who was very kind, and, in her wisdom, she gave out that if she put anything in her basket she would get a basket filled with everything she liked; so she made a hole in the lid of her basket, and put a little duck into it, and the duck into a big goose, and so she sat down in the basket, and sat all her eggs and goose in the basket. Now, if she put the duck into the hole, there was a duck in the lid, and when she was in the basket, she was quite happy. She was a good fairy, and, and had many children, but she thought she was a witch. Now, when she was in the basket, and she had been sitting awhile, she began to think the duck had never eaten, and was quite tired, and, if it had eaten her, then she should be able to fly, and sit on the duck, and so she sat on the duck; but there was no

# %% [markdown]
# ---

# %%
checkpoint_path_49965 = "models_gpt2_medium/results/checkpoint-49965"

# %%
tokenizer_49965 = AutoTokenizer.from_pretrained(checkpoint_path_49965)
model_49965 = AutoModelForCausalLM.from_pretrained(checkpoint_path_49965).to("cuda")

# %%
pipe_ckpt_49965 = pipeline(
    "text-generation",
    model=model_49965,
    tokenizer=tokenizer_49965,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
ft_output_49965 = pipe_ckpt_49965(
    prompt,
    max_new_tokens=200,
    min_new_tokens=100,
    do_sample=True,
    temperature=0.9,
    top_p=0.95,
    #repetition_penalty=1.1,
    #no_repeat_ngram_size=3
)

finetuned_49965 = ft_output_49965[0]["generated_text"]
print(finetuned_49965)
# Out:
# Once upon a time there was a fairy who lived in a fairy palace. Her husband was a brave brave little man, but she was very poor, and lived in one room with only one window. She had a small son, and he was so poor that he had nothing to eat. She was so unhappy when she got out of her fairy life, that she took him in, and gave him to a black horse, and set him up for a ride to the town, and led him over hill and dale, and she and the golden pigeon to the palace, and was soothed by the magic touch of her magic shoe, that he got up on a black horse, and she took her own, and they went, and she and her husband followed. She then asked him to go with her, and they went over hill and dale, and they came to the church, and lay down at the palace, but a mighty storm was making the wind blow, and when they reached the palace, they had to cross

# %% [markdown]
# ---

# %%
checkpoint_path_66620 = "models_gpt2_medium/results/checkpoint-66620"

# %%
tokenizer_66620 = AutoTokenizer.from_pretrained(checkpoint_path_66620)
model_66620 = AutoModelForCausalLM.from_pretrained(checkpoint_path_66620).to("cuda")

# %%
pipe_ckpt_66620 = pipeline(
    "text-generation",
    model=model_66620,
    tokenizer=tokenizer_66620,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
ft_output_66620 = pipe_ckpt_66620(
    prompt,
    max_new_tokens=200,
    min_new_tokens=100,
    do_sample=True,
    temperature=0.9,
    top_p=0.95,
    #repetition_penalty=1.1,
    #no_repeat_ngram_size=3
)

finetuned_66620 = ft_output_66620[0]["generated_text"]
print(finetuned_66620)
# Out:
# Once upon a time there was a fairy princess, who was very wise, and had a cat which she called Snowdrop. Now, when she was little, she had become very poor, and had no money; but when she was seven years of age, her mother gave her a watch, and a pair of scissors, and said, ‘Stick, and cut, and cut, till you have a long tail; then you can cut it.’ ‘Ah!’ said the fairy, ‘that is no good, for when you have a long tail, there’s nothing to cut it off, and we are all bound to have a long tail!’ So she went out into the wood, and cut a long tail out of a fir-tree, and lay down under a tree, and began to sew; but she found that when she tried to get the cat to be in the tree, it had no power to stir; so she took a knife, and began to cut

# %% [markdown]
# ---

# %%
checkpoint_path_83275 = "models_gpt2_medium/results/checkpoint-83275"

# %%
tokenizer_83275 = AutoTokenizer.from_pretrained(checkpoint_path_83275)
model_83275 = AutoModelForCausalLM.from_pretrained(checkpoint_path_83275).to("cuda")

# %%
pipe_ckpt_83275 = pipeline(
    "text-generation",
    model=model_83275,
    tokenizer=tokenizer_83275,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
ft_output_83275 = pipe_ckpt_83275(
    prompt,
    max_new_tokens=200,
    min_new_tokens=100,
    do_sample=True,
    temperature=0.9,
    top_p=0.95,
    #repetition_penalty=1.1,
    #no_repeat_ngram_size=3
)

finetuned_83275 = ft_output_83275[0]["generated_text"]
print(finetuned_83275)
# Out:
# Once upon a time there was a fairy who had three daughters; but when one of them grew old and her mother died, the eldest daughter was left in the care of her father, and he had no children of her own. One day the eldest son set out to seek a place, and as he was very poor, but he did not tell his father of his intention, and went out looking for three months, and three and twenty days, and three and twenty-four, and then he went into the forest, but he could find no way, for the eldest daughter was so beautiful and fair, she was left out in the wood; and when he came to the first brook, the second came, and when he saw the same thing, he said, ‘Well, I should like to try my luck,’ said he, ‘if I, ‘if there is no other way, I will try my luck; but if I cannot, I shall be left alone; and so the eldest daughter

# %% [markdown]
# ---

# %% [markdown]
# ## Self-BLEU

# %% [markdown]
# Self-BLEU quantifies how similar the generated samples are to each other.
#   - High Self-BLEU  → low diversity (many similar generations)
#   - Low Self-BLEU   → high diversity (more varied generations)

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# %%
def self_bleu(texts, n_gram=2):
    """
    texts: list of generated strings
    n_gram: BLEU-n (2 or 3 recommended)
    """
    smoothie = SmoothingFunction().method1
    scores = []

    weights = {
        2: (0.5, 0.5),
        3: (1/3, 1/3, 1/3),
        4: (0.25, 0.25, 0.25, 0.25)
    }[n_gram]

    tokenized = [t.lower().split() for t in texts]

    for i, hypothesis in enumerate(tokenized):
        references = tokenized[:i] + tokenized[i+1:]
        score = sentence_bleu(
            references,
            hypothesis,
            weights=weights,
            smoothing_function=smoothie
        )
        scores.append(score)

    return sum(scores) / len(scores)

# %%
def generate_samples(pipe, prompt, n=30):
    return [
        pipe(
            prompt,
            max_new_tokens=200,
            min_new_tokens=100,
            do_sample=True,
            temperature=0.9,
            top_p=0.95,
            #repetition_penalty=1.1,
            #no_repeat_ngram_size=3
        )[0]["generated_text"]
        for _ in range(n)
    ]

# %%
pipe_16655 = pipeline(
    "text-generation",
    model=model_16655,
    tokenizer=tokenizer_16655,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
pipe_33310 = pipeline(
    "text-generation",
    model=model_33310,
    tokenizer=tokenizer_33310,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
pipe_49965 = pipeline(
    "text-generation",
    model=model_49965,
    tokenizer=tokenizer_49965,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
pipe_66620 = pipeline(
    "text-generation",
    model=model_66620,
    tokenizer=tokenizer_66620,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
pipe_83275 = pipeline(
    "text-generation",
    model=model_83275,
    tokenizer=tokenizer_83275,
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
baseline_texts = generate_samples(pipe_base, prompt, n=30)
finetuned_texts_16655 = generate_samples(pipe_16655, prompt, n=30)
finetuned_texts_33310 = generate_samples(pipe_33310, prompt, n=30)
finetuned_texts_49965 = generate_samples(pipe_49965, prompt, n=30)
finetuned_texts_66620 = generate_samples(pipe_66620, prompt, n=30)
finetuned_texts_83275 = generate_samples(pipe_83275, prompt, n=30)

print("Baseline Self-BLEU:", self_bleu(baseline_texts, n_gram=2))
print("Finetuned Self-BLEU_16655:", self_bleu(finetuned_texts_16655, n_gram=2))
print("Finetuned Self-BLEU_33310:", self_bleu(finetuned_texts_33310, n_gram=2))
print("Finetuned Self-BLEU_49965:", self_bleu(finetuned_texts_49965, n_gram=2))
print("Finetuned Self-BLEU_66620:", self_bleu(finetuned_texts_66620, n_gram=2))
print("Finetuned Self-BLEU_83275:", self_bleu(finetuned_texts_83275, n_gram=2))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Baseline Self-BLEU: 0.4559352899149688
# Finetuned Self-BLEU_16655: 0.6397364478040652
# Finetuned Self-BLEU_33310: 0.6448431857062383
# Finetuned Self-BLEU_49965: 0.6152940920648863
# Finetuned Self-BLEU_66620: 0.5969490224560895
# Finetuned Self-BLEU_83275: 0.605321336817413

# %% [markdown]
# **Result**: fine-tuning increases stylistic focus at the cost of diversity, but less than in the case of gpt2-small.

# %% [markdown]
# ---

# %% [markdown]
# ## Lexical Diversity

# %% [markdown]
# Distinct-n is defined as (unique n-grams) / (total n-grams)
#
#   - Higher Distinct-n → more diverse and less repetitive text
#   - Lower Distinct-n  → more repetition / mode collapse

# %%
def distinct_n(texts, n=2):
    """
    texts: list of strings OR a single string
    n: n-gram size
    """
    # Allow single string input
    if isinstance(texts, str):
        texts = [texts]

    all_ngrams = []
    total_ngrams = 0

    for text in texts:
        tokens = text.lower().split()
        ngrams = list(zip(*[tokens[i:] for i in range(n)]))
        all_ngrams.extend(ngrams)
        total_ngrams += len(ngrams)

    return len(set(all_ngrams)) / max(1, total_ngrams)

# %%
print("Distinct-2 (base):", distinct_n(baseline_texts, 2))
print("Distinct-2 (ft):  ", distinct_n(finetuned_texts_16655, 2))
print("Distinct-2 (ft):  ", distinct_n(finetuned_texts_33310, 2))
print("Distinct-2 (ft):  ", distinct_n(finetuned_texts_49965, 2))
print("Distinct-2 (ft):  ", distinct_n(finetuned_texts_66620, 2))
print("Distinct-2 (ft):  ", distinct_n(finetuned_texts_83275, 2))
# Out:
# Distinct-2 (base): 0.6680885638838107
# Distinct-2 (ft):   0.5714285714285714
# Distinct-2 (ft):   0.5559906029757243
# Distinct-2 (ft):   0.5785939968404423
# Distinct-2 (ft):   0.5678887993553586
# Distinct-2 (ft):   0.5828651685393258

# %% [markdown]
# **Result**: complementary to self-BLEU. Fine-tuning increases stylistic focus at the cost of diversity, but less than with gpt2-small.

# %% [markdown]
# ---

# %% [markdown]
# ## Surprisal (novelty vs generic English)

# %% [markdown]
# Surprisal measures how unexpected a text is according to the model:
#   - Lower surprisal → text is more likely / more familiar to the model
#   - Higher surprisal → text is more unexpected
#
# In this experiment, surprisal is used to evaluate how generated texts
# (baseline vs fine-tuned) are perceived by the *base* GPT-2 model.

# %%
def surprisal(model, tokenizer, texts):
    """
    texts: str or list[str]
    Returns:
        - float surprisal for single text
        - average surprisal for list of texts (token-length weighted)
    """
    # Allow single string input
    if isinstance(texts, str):
        texts = [texts]

    total_loss = 0.0
    total_tokens = 0

    model.eval()

    with torch.no_grad():
        for text in texts:
            inputs = tokenizer(text, return_tensors="pt").to(model.device)
            outputs = model(**inputs, labels=inputs["input_ids"])
            loss = outputs.loss  # mean loss over tokens
            n_tokens = inputs["input_ids"].numel()

            total_loss += loss.item() * n_tokens
            total_tokens += n_tokens

    return total_loss / max(1, total_tokens)

# %%
base_surprisal = surprisal(pipe_base.model, pipe_base.tokenizer, baseline_texts)
ft_surprisal_16655 = surprisal(pipe_base.model, pipe_base.tokenizer, finetuned_texts_16655)
ft_surprisal_33310 = surprisal(pipe_base.model, pipe_base.tokenizer, finetuned_texts_33310)
ft_surprisal_49965 = surprisal(pipe_base.model, pipe_base.tokenizer, finetuned_texts_49965)
ft_surprisal_66620 = surprisal(pipe_base.model, pipe_base.tokenizer, finetuned_texts_66620)
ft_surprisal_83275 = surprisal(pipe_base.model, pipe_base.tokenizer, finetuned_texts_83275)

print("Surprisal (base):", base_surprisal)
print("Surprisal (ft):  ", ft_surprisal_16655)
print("Surprisal (ft):  ", ft_surprisal_33310)
print("Surprisal (ft):  ", ft_surprisal_49965)
print("Surprisal (ft):  ", ft_surprisal_66620)
print("Surprisal (ft):  ", ft_surprisal_83275)
# Out:
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# Surprisal (base): 1.8919601003328959
# Surprisal (ft):   2.6380428949991863
# Surprisal (ft):   2.5739039897918703
# Surprisal (ft):   2.4260239798320677
# Surprisal (ft):   2.41867679100538
# Surprisal (ft):   2.4283162140154797

# %% [markdown]
# **Result**: fine-tuning induces a stylistic specialization, making generated texts increasingly fairy-tale-like and less aligned with the base model’s general-language distribution.

# %% [markdown]
# ---

# %% [markdown]
# ## Style alignment (fairy-tale vocabulary)

# %%
fairy_words = {
    # Core beings & roles
    "fairy", "fairies", "king", "queen", "prince", "princess",
    "witch", "wizard", "sorcerer", "sorceress", "mage",
    "giant", "ogre", "dragon", "elf", "dwarf", "goblin",
    "knight", "hero", "villain",

    # Magic & supernatural
    "magic", "magical", "spell", "spells", "curse", "cursed",
    "enchantment", "enchanted", "charm", "potion",
    "wand", "crystal", "prophecy", "destiny",

    # Places & settings
    "forest", "woods", "kingdom", "castle", "tower",
    "palace", "village", "cottage", "hut",
    "mountain", "cave", "river", "lake",

    # Objects & symbols
    "crown", "throne", "sword", "shield", "cloak",
    "ring", "mirror", "key", "treasure", "gold",
    "apple", "rose", "needle",

    # Fairy-tale actions & themes
    "wish", "wished", "dream", "dreamed",
    "journey", "quest", "trial",
    "promise", "forbidden",
    "curse", "blessing",
    "transformed", "transformation",

    # Narrative markers
    "once", "kingdom", "ancient", "mystical",
    "legend", "tale", "story", "myth"
}

# %%
def fairy_score(texts):
    """
    texts: str or list[str]
    Returns:
        - int for single text
        - average fairy-word count per text for list of texts
    """
    # Allow single string input
    if isinstance(texts, str):
        texts = [texts]

    scores = []

    for text in texts:
        tokens = set(text.lower().split())
        scores.append(len(tokens & fairy_words))

    return sum(scores) / max(1, len(scores))

print("Fairy score (base):", fairy_score(baseline_texts))
print("Fairy score (ft):  ", fairy_score(finetuned_texts_16655))
print("Fairy score (ft):  ", fairy_score(finetuned_texts_33310))
print("Fairy score (ft):  ", fairy_score(finetuned_texts_49965))
print("Fairy score (ft):  ", fairy_score(finetuned_texts_66620))
print("Fairy score (ft):  ", fairy_score(finetuned_texts_83275))
# Out:
# Fairy score (base): 3.7
# Fairy score (ft):   2.566666666666667
# Fairy score (ft):   3.066666666666667
# Fairy score (ft):   3.4
# Fairy score (ft):   2.8
# Fairy score (ft):   3.0

# %% [markdown]
# **Result**: the base model starts with a very high fairy score already. Fine tuning might lead to a decreased fairy score if the used dataset does not contain all fairy words.

# %% [markdown]
# ---

# %% [markdown]
# ## Classifier Model as Judge

# %% [markdown]
#   - Input: a generated text (or list of texts)
#   - Candidate labels: e.g., ["fairy tale", "non-fairy tale"]
#   - Output: probability/confidence that the text is a fairy tale

# %% [markdown]
# **bart-large-mnli**:
#   - a sequence-to-sequence transformer model (BART) fine-tuned on MNLI (Multi-Genre Natural Language Inference)
#   - takes a premise and a hypothesis and predicts whether the premise entails, contradicts, or is neutral with respect to the hypothesis
#   - allows zero-shot classification without fine-tuning
#   - is large enough to understand nuanced stylistic cues and therefore detect stylistic differences
#   - is robust and widely used

# %% [markdown]
# **bart-large-mnli**:
#   - a sequence-to-sequence transformer model (BART) fine-tuned on MNLI (Multi-Genre Natural Language Inference)
#   - takes a premise and a hypothesis and predicts whether the premise entails, contradicts, or is neutral with respect to the hypothesis
#   - allows zero-shot classification without fine-tuning
#   - is large enough to understand nuanced stylistic cues and therefore detect stylistic differences
#   - is robust and widely used

# %%
fairytale_classifier = pipeline(
    "zero-shot-classification",
    model="facebook/bart-large-mnli",
    device="cuda"
)
# Out:
# Device set to use cuda

# %%
def fairytale_scores_zs(texts, batch_size=8):
    """
    texts: list[str]
    returns: list[float]  # P(fairy tale)
    """
    results = fairytale_classifier(
        texts,
        candidate_labels=[
            "fairy tale",
            "news article",
            "scientific text",
            "modern novel"
        ],
        hypothesis_template="This text is a {}.",
        batch_size=batch_size
    )

    # When input is a list, transformers returns a list of dicts
    scores = []
    for r in results:
        label_scores = dict(zip(r["labels"], r["scores"]))
        scores.append(label_scores["fairy tale"])

    return scores

# %%
baseline_fairy_scores = fairytale_scores_zs(baseline_texts)
finetuned_fairy_scores_16655 = fairytale_scores_zs(finetuned_texts_16655)
finetuned_fairy_scores_33310 = fairytale_scores_zs(finetuned_texts_33310)
finetuned_fairy_scores_49965 = fairytale_scores_zs(finetuned_texts_49965)
finetuned_fairy_scores_66620 = fairytale_scores_zs(finetuned_texts_66620)
finetuned_fairy_scores_83275 = fairytale_scores_zs(finetuned_texts_83275)

# %%
import numpy as np

print("Baseline fairy score:")
print("  mean =", np.mean(baseline_fairy_scores))
print("  std  =", np.std(baseline_fairy_scores))

print("Finetuned fairy score 16655:")
print("  mean =", np.mean(finetuned_fairy_scores_16655))
print("  std  =", np.std(finetuned_fairy_scores_16655))

print("Finetuned fairy score 33310:")
print("  mean =", np.mean(finetuned_fairy_scores_33310))
print("  std  =", np.std(finetuned_fairy_scores_33310))

print("Finetuned fairy score 49965:")
print("  mean =", np.mean(finetuned_fairy_scores_49965))
print("  std  =", np.std(finetuned_fairy_scores_49965))

print("Finetuned fairy score 66620:")
print("  mean =", np.mean(finetuned_fairy_scores_66620))
print("  std  =", np.std(finetuned_fairy_scores_66620))

print("Finetuned fairy score 83275:")
print("  mean =", np.mean(finetuned_fairy_scores_83275))
print("  std  =", np.std(finetuned_fairy_scores_83275))
# Out:
# Baseline fairy score:
#   mean = 0.7046054641405741
#   std  = 0.15810612327178553
# Finetuned fairy score 16655:
#   mean = 0.8531727174917857
#   std  = 0.04809949510021633
# Finetuned fairy score 33310:
#   mean = 0.8695133248964946
#   std  = 0.045276906129500576
# Finetuned fairy score 49965:
#   mean = 0.8719386716683706
#   std  = 0.04946713363723979
# Finetuned fairy score 66620:
#   mean = 0.8713482062021891
#   std  = 0.06504141575353616
# Finetuned fairy score 83275:
#   mean = 0.8757662494977315
#   std  = 0.051196134639457214

# %% [markdown]
# **Result**: the zero-shot classifier confirms that fine-tuning only moderately shifts GPT-2-large toward fairy-tale style, much less than GPT-2-small.

# %%
import pandas as pd
import numpy as np

# List of checkpoints
checkpoints = ["base", 16655, 33310, 49965, 66620, 83275]

# Self-BLEU
self_bleu_values = [
    self_bleu(baseline_texts, n_gram=2),
    self_bleu(finetuned_texts_16655, n_gram=2),
    self_bleu(finetuned_texts_33310, n_gram=2),
    self_bleu(finetuned_texts_49965, n_gram=2),
    self_bleu(finetuned_texts_66620, n_gram=2),
    self_bleu(finetuned_texts_83275, n_gram=2)
]

# Distinct-2
distinct2_values = [
    distinct_n(baseline_texts, 2),
    distinct_n(finetuned_texts_16655, 2),
    distinct_n(finetuned_texts_33310, 2),
    distinct_n(finetuned_texts_49965, 2),
    distinct_n(finetuned_texts_66620, 2),
    distinct_n(finetuned_texts_83275, 2)
]

# Surprisal under base model
surprisal_values = [
    base_surprisal,
    ft_surprisal_16655,
    ft_surprisal_33310,
    ft_surprisal_49965,
    ft_surprisal_66620,
    ft_surprisal_83275
]

# Fairy score (heuristic word overlap)
fairy_word_scores = [
    fairy_score(baseline_texts),
    fairy_score(finetuned_texts_16655),
    fairy_score(finetuned_texts_33310),
    fairy_score(finetuned_texts_49965),
    fairy_score(finetuned_texts_66620),
    fairy_score(finetuned_texts_83275)
]

# Fairy score (classifier, mean)
fairy_classifier_scores = [
    np.mean(baseline_fairy_scores),
    np.mean(finetuned_fairy_scores_16655),
    np.mean(finetuned_fairy_scores_33310),
    np.mean(finetuned_fairy_scores_49965),
    np.mean(finetuned_fairy_scores_66620),
    np.mean(finetuned_fairy_scores_83275)
]

# Fairy score std (classifier)
fairy_classifier_std = [
    np.std(baseline_fairy_scores),
    np.std(finetuned_fairy_scores_16655),
    np.std(finetuned_fairy_scores_33310),
    np.std(finetuned_fairy_scores_49965),
    np.std(finetuned_fairy_scores_66620),
    np.std(finetuned_fairy_scores_83275)
]

# Build the DataFrame
df_metrics = pd.DataFrame({
    "checkpoint": checkpoints,
    "self_bleu": self_bleu_values,
    "distinct_2": distinct2_values,
    "surprisal_base_model": surprisal_values,
    "fairy_word_score": fairy_word_scores,
    "fairy_classifier_mean": fairy_classifier_scores,
    "fairy_classifier_std": fairy_classifier_std
})

# Save to CSV
df_metrics.to_csv("fairytale_finetuning_metrics_gpt2_medium_unrestricted.csv", index=False)

print(df_metrics)
# Out:
#   checkpoint  self_bleu  distinct_2  surprisal_base_model  fairy_word_score  \
# 0       base   0.455935    0.668089              1.891960          3.700000
# 1      16655   0.639736    0.571429              2.638043          2.566667
# 2      33310   0.644843    0.555991              2.573904          3.066667
# 3      49965   0.615294    0.578594              2.426024          3.400000
# 4      66620   0.596949    0.567889              2.418677          2.800000
# 5      83275   0.605321    0.582865              2.428316          3.000000
#
#    fairy_classifier_mean  fairy_classifier_std
# 0               0.704605              0.158106
# 1               0.853173              0.048099
# 2               0.869513              0.045277
# 3               0.871939              0.049467
# 4               0.871348              0.065041
# 5               0.875766              0.051196
